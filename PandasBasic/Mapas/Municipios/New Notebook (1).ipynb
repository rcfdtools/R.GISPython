# %%
# %run -i D:\R.GISPython\GISListLayerField\GISListLayerFieldArcGIS.py
# Out:
# ----------------------------------------------------------------------------------------------------
# Consulta de capas vectoriales, propiedades y atributos en proyectos geográficos - ArcGIS for Desktop
# ----------------------------------------------------------------------------------------------------
# Python versión: 3.7.11 [MSC v.1927 64 bit (AMD64)]
# Python rutas: ['D:\\R.GISPython\\GISListLayerField', 'C:\\Program Files\\ArcGIS\\Pro\\Resources\\ArcPy']
# matplotlib versión: 3.4.2
# Encuentra este script en https://github.com/rcfdtools/R.GISPython/tree/main/GISListLayerField
# Cláusulas y condiciones de uso en https://github.com/rcfdtools/R.GISPython/wiki/License
# Créditos: r.cfdtools@gmail.com
# La opción 0 muestra las capas disponibles en el directorio de trabajo, sus atributos y tipos.
# Para una capa específica muestra los atributos y permite definir dos campos para su graficación.
#
# ----------------------------
# Listado de capas disponibles
# ...
